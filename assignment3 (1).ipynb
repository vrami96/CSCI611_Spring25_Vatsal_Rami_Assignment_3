# %%
# Test yolo model
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
results = model("ss.png")

results[0].show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9d3130c78483> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8n.pt")
#       4 results = model("ss.png")
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Load Dataset
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7VS54iLYexdfOxwG1vJm")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:01<00:00, 6317.36it/s]

# %%
# train dataset
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(data="/content/Self-Driving-Cars-6/data.yaml", epochs=30, imgsz=1280, batch=16)
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Self-Driving-Cars-6/valid/labels.cache... 801 images, 0 backgrounds, 0 corrupt: 100%|██████████| 801/801 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 51/51 [00:09<00:00,  5.17it/s]
#                    all        801        944      0.951      0.899      0.961      0.832
#            Green Light         87        122      0.885      0.693      0.867      0.505
#              Red Light         74        108      0.887      0.729      0.812      0.509
#        Speed Limit 100         52         52      0.959      0.942      0.985      0.886
#        Speed Limit 110         17         17      0.805          1      0.992      0.902
#        Speed Limit 120         60         60          1      0.912      0.994      0.912
# ...

# %%
# export model
model.export(format="torchscript")
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train4/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 19, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.6.0+cu124...
# TorchScript: export success ✅ 2.0s, saved as 'runs/detect/train4/weights/best.torchscript' (11.9 MB)
#
# Export complete (3.6s)
# Results saved to /content/runs/detect/train4/weights
# Predict:         yolo predict task=detect model=runs/detect/train4/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train4/weights/best.torchscript imgsz=640 data=/content/Self-Driving-Cars-6/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train4/weights/best.torchscript'

# %%
# Utilize new model
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train4/weights/best.pt")
results = model("ss2.png")
results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
